# %%
import pandas as pd

# %%
jeopardy = pd.read_csv("jeopardy.csv")

# %%
jeopardy.head()
# Out:
#    Show Number    Air Date      Round                         Category  Value  \
# 0         4680  2004-12-31  Jeopardy!                          HISTORY   $200
# 1         4680  2004-12-31  Jeopardy!  ESPN's TOP 10 ALL-TIME ATHLETES   $200
# 2         4680  2004-12-31  Jeopardy!      EVERYBODY TALKS ABOUT IT...   $200
# 3         4680  2004-12-31  Jeopardy!                 THE COMPANY LINE   $200
# 4         4680  2004-12-31  Jeopardy!              EPITAPHS & TRIBUTES   $200
#
#                                             Question      Answer
# 0  For the last 8 years of his life, Galileo was ...  Copernicus
# 1  No. 2: 1912 Olympian; football star at Carlisl...  Jim Thorpe
# 2  The city of Yuma in this state has a record av...     Arizona
# 3  In 1963, live on "The Art Linkletter Show", th...  McDonald's
# 4  Signer of the Dec. of Indep., framer of the Co...  John Adams

# %%
jeopardy.columns = jeopardy.columns.str.strip()

# %%
jeopardy["Air Date"] = pd.to_datetime(jeopardy["Air Date"])

# %%
jeopardy = jeopardy.sort_values("Air Date")

# %%
jeopardy["Value"] = jeopardy["Value"].str.replace(r"[$,]", "", regex=True).fillna(0).astype(float)

# %%
jeopardy["Clean Question"] = jeopardy.Question.str.lower().str.replace(r"[\W\s+]"," ")
jeopardy["Clean Answer"] = jeopardy.Answer.str.lower().str.replace(r"[\W\s+]"," ")

# %%
jeopardy
# Out:
#        Show Number   Air Date             Round                 Category  \
# 19325           10 1984-09-21   Final Jeopardy!          U.S. PRESIDENTS
# 19301           10 1984-09-21  Double Jeopardy!             LABOR UNIONS
# 19302           10 1984-09-21  Double Jeopardy!                     1789
# 19303           10 1984-09-21  Double Jeopardy!            TOURIST TRAPS
# 19304           10 1984-09-21  Double Jeopardy!               LITERATURE
# ...            ...        ...               ...                      ...
# 1953          6294 2012-01-19  Double Jeopardy!  WEAPONS OF WORLD WAR II
# 1954          6294 2012-01-19  Double Jeopardy!  ACTING PRESIDENTS ON TV
# 1955          6294 2012-01-19  Double Jeopardy!                      4 N
# 1945          6294 2012-01-19  Double Jeopardy!         AMERICAN HISTORY
# 1922          6294 2012-01-19         Jeopardy!          THAT'S BUSINESS
#
#        Value                                           Question  \
# 19325    0.0  Adventurous 26th president, he was 1st to ride...
# 19301  200.0           Notorious labor leader missing since '75
# 19302  200.0  Washington proclaimed Nov. 26, 1789 this first...
# 19303  200.0  Both Ferde Grofe' & the Colorado River dug thi...
# 19304  200.0  Depending on the book, he could be a "Jones", ...
# ...      ...                                                ...
# 1953   800.0  Ships in the U.S. Navy's Casablanca class of "...
# 1954   800.0  Dennis Haysbert & D.B. Woodside as David & Way...
# 1955   800.0  "U" know it means not deliberate; I'm sorry, t...
# 1945   400.0  In December 1974 this former New York governor...
# 1922   400.0  In 1997 Tyco International moved to this U.K. ...
#
#                    Answer                                     Clean Question  \
# 19325  Theodore Roosevelt  adventurous 26th president, he was 1st to ride...
# 19301         Jimmy Hoffa           notorious labor leader missing since '75
# 19302        Thanksgiving  washington proclaimed nov. 26, 1789 this first...
# 19303    the Grand Canyon  both ferde grofe' & the colorado river dug thi...
# 19304                 Tom  depending on the book, he could be a "jones", ...
# ...                   ...                                                ...
# 1953    aircraft carriers  ships in the u.s. navy's casablanca class of "...
# 1954                   24  dennis haysbert & d.b. woodside as david & way...
# 1955        unintentional  "u" know it means not deliberate; i'm sorry, t...
# 1945          Rockefeller  in december 1974 this former new york governor...
# 1922              Bermuda  in 1997 tyco international moved to this u.k. ...
#
#              Clean Answer
# 19325  theodore roosevelt
# 19301         jimmy hoffa
# 19302        thanksgiving
# 19303    the grand canyon
# 19304                 tom
# ...                   ...
# 1953    aircraft carriers
# 1954                   24
# 1955        unintentional
# 1945          rockefeller
# 1922              bermuda
#
# [19999 rows x 9 columns]

# %% [markdown]
# # Answer in Question

# %%
def count_matches(row):
    splitted_question = row["Clean Question"].split()
    splitted_answer = row["Clean Answer"].split()
    
    if "the" in splitted_answer:
        splitted_answer.remove("the")
    
    if len(splitted_answer) == 0:
        return 0
    
    count_match = 0
    for word in splitted_answer:
        if word in splitted_question:
            count_match += 1
            
    return count_match / len(splitted_answer)

# %%
jeopardy["answer_in_question"] = jeopardy.apply(count_matches, axis = 1)

# %%
jeopardy.head()
# Out:
#        Show Number   Air Date             Round         Category  Value  \
# 19325           10 1984-09-21   Final Jeopardy!  U.S. PRESIDENTS    0.0
# 19301           10 1984-09-21  Double Jeopardy!     LABOR UNIONS  200.0
# 19302           10 1984-09-21  Double Jeopardy!             1789  200.0
# 19303           10 1984-09-21  Double Jeopardy!    TOURIST TRAPS  200.0
# 19304           10 1984-09-21  Double Jeopardy!       LITERATURE  200.0
#
#                                                 Question              Answer  \
# 19325  Adventurous 26th president, he was 1st to ride...  Theodore Roosevelt
# 19301           Notorious labor leader missing since '75         Jimmy Hoffa
# 19302  Washington proclaimed Nov. 26, 1789 this first...        Thanksgiving
# 19303  Both Ferde Grofe' & the Colorado River dug thi...    the Grand Canyon
# 19304  Depending on the book, he could be a "Jones", ...                 Tom
#
#                                           Clean Question        Clean Answer  \
# 19325  adventurous 26th president, he was 1st to ride...  theodore roosevelt
# 19301           notorious labor leader missing since '75         jimmy hoffa
# 19302  washington proclaimed nov. 26, 1789 this first...        thanksgiving
# 19303  both ferde grofe' & the colorado river dug thi...    the grand canyon
# 19304  depending on the book, he could be a "jones", ...                 tom
#
#        answer_in_question
# 19325                 0.0
# 19301                 0.0
# 19302                 0.0
# 19303                 0.0
# 19304                 0.0

# %%
jeopardy["answer_in_question"].mean()*100
# Out:
# 4.552247259382615

# %% [markdown]
# On average, the answer only makes up for about `4.55%` of the question. This isn't a huge number, and it means that we probably can't just hope that hearing a question will enable us to determine the answer. We'll probably have to study.

# %% [markdown]
# # Recycled Questions/Question Overlapped

# %%
question_overlap_percentage = []
term_used = set()

for i,row in jeopardy.iterrows():
    split_question = row["Clean Question"].split()
    split_question = [word for word in split_question if len(split_question)>5]
    
    match_count = 0
    for word in split_question:
        if word in term_used:
            match_count += 1
    
    for word in split_question:
        term_used.add(word)
        
    if len(split_question) > 0:
        match_count /= len(split_question)
        
    question_overlap_percentage.append(match_count)

# %%
jeopardy["question_overlap"] = question_overlap_percentage

# %%
jeopardy["question_overlap"].mean()*100
# Out:
# 77.52177907641111

# %% [markdown]
# # Low Value vs. High Value Questions

# %%
jeopardy["high_value"] = jeopardy["Value"].apply(lambda x: 0 if x < 800 else 1)

# %%
def count_usage(term):
    low_count = 0
    high_count = 0
    
    for i, row in jeopardy.iterrows():
        if term in row["Clean_question"].split():
            if row["high_value"] == 1:
                high_count += 1
            else:
                low_count += 1
    return low_count,high_count

# %%
from random import choice

terms_used_list = list(term_used)
comparison_terms = [choice(terms_used_list) for _ in range(10)]

observed_expected = []

for term in comparison_terms:
    observed_expected.append(count_usage(term))

observed_expected
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'clean_question'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[50], line 9
#       6 observed_expected = []
#       8 for term in comparison_terms:
# ----> 9     observed_expected.append(count_usage(term))
#      11 observed_expected
#
# Cell In[48], line 6, in count_usage(term)
#       3 high_count = 0
#       5 for i, row in jeopardy.iterrows():
# ----> 6     if term in row["clean_question"].split():
#       7         if row["high_value"] == 1:
#       8             high_count += 1
#
# File ~\anaconda3\Lib\site-packages\pandas\core\series.py:1007, in Series.__getitem__(self, key)
#    1004     return self._values[key]
#    1006 elif key_is_scalar:
# -> 1007     return self._get_value(key)
#    1009 if is_hashable(key):
#    1010     # Otherwise index.get_value will raise InvalidIndexError
#    1011     try:
#    1012         # For labels that don't resolve as scalars like tuples and frozensets
#
# File ~\anaconda3\Lib\site-packages\pandas\core\series.py:1116, in Series._get_value(self, label, takeable)
#    1113     return self._values[label]
#    1115 # Similar to Index.get_value, but we do not fall back to positional
# -> 1116 loc = self.index.get_loc(label)
#    1118 if is_integer(loc):
#    1119     return self._values[loc]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3655, in Index.get_loc(self, key)
#    3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
# -> 3655     raise KeyError(key) from err
#    3656 except TypeError:
#    3657     # If we have a listlike key, _check_indexing_error will raise
#    3658     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3659     #  the TypeError.
#    3660     self._check_indexing_error(key)
#
# KeyError: 'clean_question'
